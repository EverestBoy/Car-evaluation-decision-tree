# %%
import pandas as pd;
from sklearn.tree import DecisionTreeClassifier, export_graphviz;
from IPython.display import Image;
import pydotplus;
from sklearn.externals.six import StringIO

# %%
data = pd.read_csv('car_evaluation.csv')

# %%
# low = 0
# small = 0
# unacc = 0
# med = 1
# acc = 1
# high = 2
# big = 2
# good = 2
# vgood = 3
# vhigh = 3


data.replace('low',0, inplace=True)
data.replace('med',1, inplace=True)
data.replace('high',2, inplace=True)
data.replace('vhigh',3, inplace = True)
data.replace('small',0, inplace=True)
data.replace('big',2, inplace = True)

data.replace('unacc',0, inplace=True)
data.replace('acc',1, inplace=True)
data.replace('good',2, inplace=True)
data.replace('vgood',3, inplace = True)

# %%
data.head()
# Out:
#    buying  maint  doors  persons  lug_boot  safety  outcome
# 0       3      3      2        2         0       0        0
# 1       3      3      2        2         0       1        0
# 2       3      3      2        2         0       2        0
# 3       3      3      2        2         1       0        0
# 4       3      3      2        2         1       1        0

# %%
X = xx.loc[:,['buying', 'maint', 'doors','persons', 
               'lug_boot', 'safety']]
y = xx.outcome

# %% [markdown]
# ### Creating decision tree object

# %%
model_dtree = DecisionTreeClassifier()
model_dtree5 = DecisionTreeClassifier(max_depth=5)

# %%
model_dtree5.fit(X,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %% [markdown]
# ### Visualising

# %%
node_data = StringIO()

# %%
export_graphviz(model_dtree5, 
                out_file=node_data, 
                filled = True, 
                rounded = True, 
                feature_names = ['buing', 'maint', 'doors', 'persons', 'lug_boot','safety'] , 
                class_names= ['unacc','acc','good','vgood']
               )

# %%
# node_data.getvalue()

# %%
graph = pydotplus.graph_from_dot_data(node_data.getvalue())

# %%
Image(graph.create_png())
